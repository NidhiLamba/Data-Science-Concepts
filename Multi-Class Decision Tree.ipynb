# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Using cached graphviz-0.20.1-py3-none-any.whl (47 kB)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.1
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split 
from sklearn import metrics
import numpy as np

# %%
features = np.array([
    [29, 23, 72],
    [31, 25, 77],
    [31, 27, 82],
    [29, 29, 89],
    [31, 31, 72],
    [29, 33, 77],
]*10)

labels = np.array([
    [2], 
    [1], 
    [3], 
    [3],
    [2],
    [2],
]*10)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    features,
    labels,
    test_size=0.1,
    random_state=42)

# %%
X_test
# Out:
# array([[29, 23, 72],
#        [29, 33, 77],
#        [29, 23, 72],
#        [29, 29, 89],
#        [31, 25, 77],
#        [29, 23, 72]])

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier()
clf.fit(X=X_train, y=y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.feature_importances_
clf.score(X=X_test, y=y_test)
y_pred=clf.predict(X_test)

# %%
print(y_pred)
# Out:
# [2 2 2 3 1 2]

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %% [markdown]
# <!-- Visualising Decision Tree -->

# %% [markdown]
# #  Visualizing Decision Tree

# %%
# https://www.datacamp.com/tutorial/decision-tree-classification-python

# %%
import six
import sys
sys.modules['sklearn.externals.six'] = six

# %%
# pip install graphviz

# %%
# pip install pydotplus

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

# %%
# brew install graphviz

# %%
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = None,class_names=['1','2','3'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
# graph.write_png('MulticlassDT.png')
Image(graph.create_png())

# %%
# !pip uninstall -y graphviz
# Out:
# Found existing installation: graphviz 0.20.1
# Uninstalling graphviz-0.20.1:
#   Successfully uninstalled graphviz-0.20.1

# %%
# !brew install graphviz
# Out:
# Running `brew update --auto-update`...
# ==> Downloading https://formulae.brew.sh/api/formula.json
# ######################################################################## 100.0%
# ==> Downloading https://formulae.brew.sh/api/cask.json
# ######################################################################## 100.0%
# ==> Fetching dependencies for graphviz: libpng, freetype, fontconfig, jpeg-turbo, brotli, highway, imath, lz4, xz, zstd, little-cms2, openexr, webp, jpeg-xl, libvmaf, aom, libavif, gd, pcre2, gettext, glib, jasper, netpbm, gts, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, gdk-pixbuf, fribidi, graphite2, icu4c, harfbuzz, pango, librsvg and libtool
# ==> Fetching libpng
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/manifests/1.6.39
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/blobs/sha256:c437aaaf373
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching freetype
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.13.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/blobs/sha256:d033f5606
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching fontconfig
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/manifests/2.14.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/blobs/sha256:2e1558c
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching jpeg-turbo
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/2.1.5.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/blobs/sha256:844f7f6
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching brotli
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/manifests/1.0.9
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/blobs/sha256:5e9bddd862b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching highway
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/manifests/1.0.3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/blobs/sha256:d113ba1bce
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching imath
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/manifests/3.1.6
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/blobs/sha256:ff6169b5986b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching lz4
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/manifests/1.9.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/blobs/sha256:284fa580570efd
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching xz
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/manifests/5.4.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/blobs/sha256:3908f1a9e36d68a
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching zstd
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/manifests/1.5.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/blobs/sha256:6de68b55a5336
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching little-cms2
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/manifests/2.14
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/blobs/sha256:ae03cf
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching openexr
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/manifests/3.1.5
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/blobs/sha256:633811a87f
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching webp
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.3.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/blobs/sha256:b184d1461126f
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching jpeg-xl
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/manifests/0.8.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/blobs/sha256:f0fcfea7ac
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libvmaf
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/manifests/2.3.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/blobs/sha256:780fe80d39
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching aom
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/manifests/3.6.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/blobs/sha256:82c42edfcd3aa2
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libavif
# ==> Downloading https://ghcr.io/v2/homebrew/core/libavif/manifests/0.11.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libavif/blobs/sha256:7894a74f1c
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching gd
# ==> Downloading https://ghcr.io/v2/homebrew/core/gd/manifests/2.3.3_4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gd/blobs/sha256:22dba9b654ae0a2
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching pcre2
# ==> Downloading https://ghcr.io/v2/homebrew/core/pcre2/manifests/10.42
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pcre2/blobs/sha256:23ce93cf86bd
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching gettext
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/manifests/0.21.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/blobs/sha256:356b52e24b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching glib
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.74.6
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:6a797f2712203
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching jasper
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/manifests/4.0.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/blobs/sha256:6c01e7edfbf
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching netpbm
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/manifests/10.86.37
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/blobs/sha256:29d7bdf2039
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching gts
# ==> Downloading https://ghcr.io/v2/homebrew/core/gts/manifests/0.7.6_2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gts/blobs/sha256:5eb4dfee13280e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching xorgproto
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2022.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/blobs/sha256:d6deb2e4
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libxau
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/manifests/1.0.11
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/blobs/sha256:8f7c0378757
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libxdmcp
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/manifests/1.1.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/blobs/sha256:7ead47382
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libxcb
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/manifests/1.15_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/blobs/sha256:8a0df37f208
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libx11
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.8.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/blobs/sha256:5da752047f0
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libxext
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/manifests/1.3.5
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/blobs/sha256:4f194ef26f
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libxrender
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/manifests/0.9.11
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/blobs/sha256:660b412
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching lzo
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/manifests/2.10
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/blobs/sha256:e16072e8ef7a88
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching pixman
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/manifests/0.42.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/blobs/sha256:1e4026e8980
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching cairo
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/manifests/1.16.0_5
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/blobs/sha256:50feaae83e93
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching gdk-pixbuf
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdk-pixbuf/manifests/2.42.10-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdk-pixbuf/blobs/sha256:f944e29
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching fribidi
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/manifests/1.0.12
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/blobs/sha256:e213623dac
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching graphite2
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/manifests/1.3.14
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/blobs/sha256:2254ea02
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching icu4c
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/manifests/72.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/blobs/sha256:90c50fe2cbf8
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching harfbuzz
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/7.0.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:18ee2c2e6
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching pango
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/manifests/1.50.13
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/blobs/sha256:afde6bb8f8f4
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching librsvg
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/manifests/2.55.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/blobs/sha256:7677c86c5a
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching libtool
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/manifests/2.4.7
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/blobs/sha256:5f92327e52
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching graphviz
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/manifests/7.1.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/blobs/sha256:8c4dba8b1
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Installing dependencies for graphviz: libpng, freetype, fontconfig, jpeg-turbo, brotli, highway, imath, lz4, xz, zstd, little-cms2, openexr, webp, jpeg-xl, libvmaf, aom, libavif, gd, pcre2, gettext, glib, jasper, netpbm, gts, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, gdk-pixbuf, fribidi, graphite2, icu4c, harfbuzz, pango, librsvg and libtool
# ==> Installing graphviz dependency: libpng
# ==> Pouring libpng--1.6.39.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libpng/1.6.39: 27 files, 1.3MB
# ==> Installing graphviz dependency: freetype
# ==> Pouring freetype--2.13.0.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/freetype/2.13.0: 67 files, 2.4MB
# ==> Installing graphviz dependency: fontconfig
# ==> Pouring fontconfig--2.14.2.arm64_monterey.bottle.tar.gz
# ==> Regenerating font cache, this may take a while
# ==> /opt/homebrew/Cellar/fontconfig/2.14.2/bin/fc-cache -frv
# 🍺  /opt/homebrew/Cellar/fontconfig/2.14.2: 88 files, 2.4MB
# ==> Installing graphviz dependency: jpeg-turbo
# ==> Pouring jpeg-turbo--2.1.5.1.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/jpeg-turbo/2.1.5.1: 44 files, 2.5MB
# ==> Installing graphviz dependency: brotli
# ==> Pouring brotli--1.0.9.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/brotli/1.0.9: 25 files, 2.3MB
# ==> Installing graphviz dependency: highway
# ==> Pouring highway--1.0.3.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/highway/1.0.3: 61 files, 2.3MB
# ==> Installing graphviz dependency: imath
# ==> Pouring imath--3.1.6.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/imath/3.1.6: 49 files, 931.4KB
# ==> Installing graphviz dependency: lz4
# ==> Pouring lz4--1.9.4.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/lz4/1.9.4: 22 files, 681.5KB
# ==> Installing graphviz dependency: xz
# ==> Pouring xz--5.4.1.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/xz/5.4.1: 95 files, 1.7MB
# ==> Installing graphviz dependency: zstd
# ==> Pouring zstd--1.5.4.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/zstd/1.5.4: 31 files, 2.3MB
# ==> Installing graphviz dependency: little-cms2
# ==> Pouring little-cms2--2.14.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/little-cms2/2.14: 21 files, 1.4MB
# ==> Installing graphviz dependency: openexr
# ==> Pouring openexr--3.1.5.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/openexr/3.1.5: 194 files, 6.0MB
# ==> Installing graphviz dependency: webp
# ==> Pouring webp--1.3.0.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/webp/1.3.0: 47 files, 2.3MB
# ==> Installing graphviz dependency: jpeg-xl
# ==> Pouring jpeg-xl--0.8.1.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/jpeg-xl/0.8.1: 41 files, 10.7MB
# ==> Installing graphviz dependency: libvmaf
# ==> Pouring libvmaf--2.3.1.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libvmaf/2.3.1: 234 files, 7MB
# ==> Installing graphviz dependency: aom
# ==> Pouring aom--3.6.0.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/aom/3.6.0: 23 files, 8.7MB
# ==> Installing graphviz dependency: libavif
# ==> Pouring libavif--0.11.1.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libavif/0.11.1: 19 files, 496.6KB
# ==> Installing graphviz dependency: gd
# ==> Pouring gd--2.3.3_4.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gd/2.3.3_4: 33 files, 1.5MB
# ==> Installing graphviz dependency: pcre2
# ==> Pouring pcre2--10.42.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pcre2/10.42: 230 files, 6.2MB
# ==> Installing graphviz dependency: gettext
# ==> Pouring gettext--0.21.1.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gettext/0.21.1: 1,983 files, 20.9MB
# ==> Installing graphviz dependency: glib
# ==> Pouring glib--2.74.6.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/glib/2.74.6: 449 files, 21.9MB
# ==> Installing graphviz dependency: jasper
# ==> Pouring jasper--4.0.0.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/jasper/4.0.0: 44 files, 1.6MB
# ==> Installing graphviz dependency: netpbm
# ==> Pouring netpbm--10.86.37.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/netpbm/10.86.37: 408 files, 18.5MB
# ==> Installing graphviz dependency: gts
# ==> Pouring gts--0.7.6_2.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gts/0.7.6_2: 26 files, 1.6MB
# ==> Installing graphviz dependency: xorgproto
# ==> Pouring xorgproto--2022.2.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/xorgproto/2022.2: 268 files, 3.9MB
# ==> Installing graphviz dependency: libxau
# ==> Pouring libxau--1.0.11.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxau/1.0.11: 21 files, 123.5KB
# ==> Installing graphviz dependency: libxdmcp
# ==> Pouring libxdmcp--1.1.4.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxdmcp/1.1.4: 11 files, 130.4KB
# ==> Installing graphviz dependency: libxcb
# ==> Pouring libxcb--1.15_1.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxcb/1.15_1: 2,461 files, 7.3MB
# ==> Installing graphviz dependency: libx11
# ==> Pouring libx11--1.8.4.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libx11/1.8.4: 1,054 files, 7MB
# ==> Installing graphviz dependency: libxext
# ==> Pouring libxext--1.3.5.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxext/1.3.5: 87 files, 445.8KB
# ==> Installing graphviz dependency: libxrender
# ==> Pouring libxrender--0.9.11.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxrender/0.9.11: 12 files, 213.9KB
# ==> Installing graphviz dependency: lzo
# ==> Pouring lzo--2.10.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/lzo/2.10: 31 files, 565.6KB
# ==> Installing graphviz dependency: pixman
# ==> Pouring pixman--0.42.2.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pixman/0.42.2: 11 files, 842.5KB
# ==> Installing graphviz dependency: cairo
# ==> Pouring cairo--1.16.0_5.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/cairo/1.16.0_5: 126 files, 6.4MB
# ==> Installing graphviz dependency: gdk-pixbuf
# ==> Pouring gdk-pixbuf--2.42.10.arm64_monterey.bottle.1.tar.gz
# ==> /opt/homebrew/Cellar/gdk-pixbuf/2.42.10/bin/gdk-pixbuf-query-loaders --updat
# 🍺  /opt/homebrew/Cellar/gdk-pixbuf/2.42.10: 150 files, 3.9MB
# ==> Installing graphviz dependency: fribidi
# ==> Pouring fribidi--1.0.12.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/fribidi/1.0.12: 67 files, 662.1KB
# ==> Installing graphviz dependency: graphite2
# ==> Pouring graphite2--1.3.14.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/graphite2/1.3.14: 18 files, 280.6KB
# ==> Installing graphviz dependency: icu4c
# ==> Pouring icu4c--72.1.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/icu4c/72.1: 263 files, 78.4MB
# ==> Installing graphviz dependency: harfbuzz
# ==> Pouring harfbuzz--7.0.1.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/harfbuzz/7.0.1: 76 files, 8.8MB
# ==> Installing graphviz dependency: pango
# ==> Pouring pango--1.50.13.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pango/1.50.13: 68 files, 3.4MB
# ==> Installing graphviz dependency: librsvg
# ==> Pouring librsvg--2.55.1.arm64_monterey.bottle.tar.gz
# ==> /opt/homebrew/opt/gdk-pixbuf/bin/gdk-pixbuf-query-loaders --update-cache
# 🍺  /opt/homebrew/Cellar/librsvg/2.55.1: 24 files, 54.5MB
# ==> Installing graphviz dependency: libtool
# ==> Pouring libtool--2.4.7.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libtool/2.4.7: 75 files, 3.8MB
# ==> Installing graphviz
# ==> Pouring graphviz--7.1.0.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/graphviz/7.1.0: 328 files, 13.4MB
# ==> Running `brew cleanup graphviz`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Upgrading 2 dependents of upgraded formulae:
# Disable this behaviour by setting HOMEBREW_NO_INSTALLED_DEPENDENTS_CHECK.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# qt@5 5.15.6 -> 5.15.8_2, pyqt@5 5.15.7_1 -> 5.15.7_2
# ==> Fetching qt@5
# ==> Downloading https://ghcr.io/v2/homebrew/core/qt/5/manifests/5.15.8_2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/qt/5/blobs/sha256:a979309fc7109
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Fetching pyqt@5
# ==> Downloading https://ghcr.io/v2/homebrew/core/pyqt/5/manifests/5.15.7_2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pyqt/5/blobs/sha256:65d02cc5903
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Upgrading qt@5
#   5.15.6 -> 5.15.8_2
#
# ==> Pouring qt@5--5.15.8_2.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/qt@5/5.15.8_2: 10,840 files, 344.4MB
# ==> Running `brew cleanup qt@5`...
# Removing: /opt/homebrew/Cellar/qt@5/5.15.6... (10,847 files, 344.2MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/qt@5--5.15.6... (115.4MB)
# ==> Upgrading pyqt@5
#   5.15.7_1 -> 5.15.7_2
#
# ==> Pouring pyqt@5--5.15.7_2.arm64_monterey.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pyqt@5/5.15.7_2: 3,966 files, 102MB
# ==> Running `brew cleanup pyqt@5`...
# Removing: /opt/homebrew/Cellar/pyqt@5/5.15.7_1... (2,647 files, 67.9MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/pyqt@5--5.15.7_1... (13.3MB)
# ==> Checking for dependents of upgraded formulae...
# ==> No broken dependents found!
# ==> `brew cleanup` has not been run in the last 30 days, running now...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/autoconf--2.71... (944.1KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/ca-certificates--2022-07-19_1... (125.8KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/coreutils--9.1... (4.2MB)
# Removing: /opt/homebrew/Cellar/freetype/2.12.1... (67 files, 2.3MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/freetype--2.12.1... (890.3KB)
# Removing: /opt/homebrew/Cellar/gettext/0.21... (1,953 files, 20.6MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/gettext--0.21... (8.7MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/giflib--5.2.1... (148.8KB)
# Removing: /opt/homebrew/Cellar/glib/2.74.0... (448 files, 21.8MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/glib--2.74.0... (6.4MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/gmp--6.2.1_1... (1006.7KB)
# Removing: /opt/homebrew/Cellar/jpeg-turbo/2.1.4... (44 files, 2.5MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/jpeg-turbo--2.1.4... (825.9KB)
# Removing: /opt/homebrew/Cellar/libpng/1.6.38... (27 files, 1.3MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/libpng--1.6.38... (448KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/libtiff--4.4.0_1... (1.2MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/m4--1.4.19... (256.0KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/openssl@1.1--1.1.1q... (5MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/pcre--8.45... (1.4MB)
# Removing: /opt/homebrew/Cellar/pcre2/10.40... (230 files, 6.1MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/pcre2--10.40... (2.0MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/pkg-config--0.29.2_3... (237.2KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/pyenv--2.3.4... (705.8KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/readline--8.1.2... (560.3KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/swig--4.0.2... (1.5MB)
# Removing: /opt/homebrew/Cellar/webp/1.2.4... (41 files, 2.2MB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/webp--1.2.4... (756.4KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/descriptions.json... (345.6KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/cask_descriptions.json... (260.4KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/pyenv_bottle_manifest--2.3.4... (22.3KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/gmp_bottle_manifest--6.2.1_1... (7.4KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/m4_bottle_manifest--1.4.19... (7.0KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/pcre_bottle_manifest--8.45... (8.6KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/openssl@1.1_bottle_manifest--1.1.1q... (7.6KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/qt@5_bottle_manifest--5.15.6... (37.4KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/libtiff_bottle_manifest--4.4.0_1... (7KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/pyqt@5_bottle_manifest--5.15.7_1... (24.3KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/jpeg-turbo_bottle_manifest--2.1.4... (7.2KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/swig_bottle_manifest--4.0.2... (7.8KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/freetype_bottle_manifest--2.12.1... (7KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/libpng_bottle_manifest--1.6.38... (6.5KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/giflib_bottle_manifest--5.2.1... (7.2KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/ca-certificates_bottle_manifest--2022-07-19_1... (1.8KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/autoconf_bottle_manifest--2.71... (9.4KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/gettext_bottle_manifest--0.21... (10.5KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/glib_bottle_manifest--2.74.0... (11.7KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/readline_bottle_manifest--8.1.2... (6.6KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/coreutils_bottle_manifest--9.1... (6.6KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/pkg-config_bottle_manifest--0.29.2_3... (7.4KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/pcre2_bottle_manifest--10.40... (7.5KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/webp_bottle_manifest--1.2.4... (8.8KB)
# Removing: /Users/uchreetinsan/Library/Caches/Homebrew/Cask/iterm2--3.4.16.zip... (23MB)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/pyenv... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/pkg-config... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/libtiff... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/coreutils... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/gmp... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/swig... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/libpng... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/pyqt@5... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/qt@5... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/freetype... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/glib... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/readline... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/webp... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/giflib... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/ca-certificates... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/gettext... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/autoconf... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/m4... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/pcre2... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/openssl@1.1... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/pcre... (64B)
# Removing: /Users/uchreetinsan/Library/Logs/Homebrew/jpeg-turbo... (64B)
# Pruned 0 symbolic links and 4 directories from /opt/homebrew

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0
